# %%
abs(-70)
# Out:
# 70

# %%
abs(-70.12)
# Out:
# 70.12

# %%
pow(2,3)
# Out:
# 8

# %%
pow(10,2)
# Out:
# 100

# %%
pow(10,-2)
# Out:
# 0.01

# %%
pow(10,2,3)
# Out:
# 1

# %%
round(4.4)
# Out:
# 4

# %%
round(4.6)
# Out:
# 5

# %%
round(3.556891)
# Out:
# 4

# %%
round(3.556891,2)
# Out:
# 3.56

# %%
divmod(10,3)
# Out:
# (3, 1)

# %%
divmod(61,7)
# Out:
# (8, 5)

# %%
min(-10,2,3,4-7)
# Out:
# -10

# %%
min([-10,2,3,4-7],key=abs)
# Out:
# 2

# %%
min([],default="empty list")
# Out:
# 'empty list'

# %%
sum([1,2,3,4])
# Out:
# 10

# %%
eval("10+20*4-5")
# Out:
# 85

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
x=10
print(isinstance(x,int))
# Out:
# True

# %%
text='hello'

# %%
hasattr(text,'lower')
# Out:
# True

# %%
hasattr(text,'search')
# Out:
# False

# %%
hasattr(text,'find')
# Out:
# True

# %%
import math

# %%
getattr(math,'pi')
# Out:
# 3.141592653589793

# %%
getattr(math,'sqrt')(25)
# Out:
# 5.0

# %%
x=11
y=11
print(id(x))
print(id(y))
# Out:
# 140727747519720
# 140727747519720

# %%
l1=[1,2,3,4,5]
l2=[1,2,3,4,5]

# %%
print(id(l1))
print(id(l1))
# Out:
# 2550840189440
# 2550840189440

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
text='hello worls'
repr(text)
# Out:
# "'hello worls'"

# %%
list1=[1,2,3,4,-7]
sorted(list1)
# Out:
# [-7, 1, 2, 3, 4]

# %%
sorted(list1,reverse=True)
# Out:
# [4, 3, 2, 1, -7]

# %%
list1=[1,23,43,-7]
reversed(list1)

# %%
s=slice(5)
list1[s]
# Out:
# [1, 23, 43, -7]

# %%
list1=[10,12]
it=iter(list1)
next(it)
# Out:
# 10

# %%
next(it)
# Out:
# 12
