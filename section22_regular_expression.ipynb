# %%
import re

# %%
re.match('abc','abcdef')
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
re.fullmatch('python','python').group()
# Out:
# 'python'

# %%
re.search('very','python is very easy').span()
# Out:
# (10, 14)

# %%
re.findall('can','can you can as a canner')
# Out:
# ['can', 'can', 'can']

# %% [raw]
# QUANTIFIERS

# %%
re.fullmatch('(ab)?','ab')
# Out:
# <re.Match object; span=(0, 2), match='ab'>

# %%
re.fullmatch('(ab)?','')
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
re.fullmatch('(ab)*','')
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
re.fullmatch('(ab)*','ababababababab')
# Out:
# <re.Match object; span=(0, 14), match='ababababababab'>

# %%
re.findall('[abc]+','123 abc 987 bbc')
# Out:
# ['abc', 'bbc']

# %% [markdown]
# SPECIAL CHARACTERS
