# %%
l1=[x for x in range(1,5)]

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l1=[x**2 for x in range(1,5)]
l1
# Out:
# [1, 4, 9, 16]

# %%
l1=[x.lower() for x in 'PYthoN']
l1
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
l1=[int(x) for x in '12345']
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1=[x for x in '1ab*23d45f' if x.isalpha()]
l1
# Out:
# ['a', 'b', 'd', 'f']

# %%
l1=[[1,2],[3,4],[5,6]]
l1[0]
l1[0][1]
l1[2][0]
# Out:
# 5

# %%
# Given list of numbers, list can be tested for different numbers

nums = [4, 8, 3, 5, 10, 7, 2, 9, 13, 6]

# TODO: Create a list of all odd numbers from nums using list comptrehension.

odd = [x for x in nums if x%2 !=0]

# TODO: Create a list of all even numbers from nums from nums using list comptrehension.

even = [x for x in nums if x%2 ==0]


# Print the odd and even lists
print('Odd:', odd)
print('Even:', even)
# Out:
# Odd: [3, 5, 7, 9, 13]
# Even: [4, 8, 10, 2, 6]

# %%
l1=[[1,2,54],[3,4,1,2,3,4],[5,6,6,7,8,10,9]]
max_list=max(l1,key=len)
print(max_list)
# Out:
# [5, 6, 6, 7, 8, 10, 9]
