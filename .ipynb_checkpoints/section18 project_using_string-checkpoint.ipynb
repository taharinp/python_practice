# %% [raw]
# restaurant menu

# %%
item1='hot dog'
i2='donuts'
i3='burgur'
i4='pizza'

price1='30'
p2='23'
p3='56'
p4='67'



dash='-'*10
#dash=20-len(item1)-len(price1)
print(item1+dash+price1)
print(i2+dash+p2)
print(i3+dash+p3)
print(i4+dash+p4)
# Out:
# hot dog----------30
# donuts----------23
# burgur----------56
# pizza----------67

# %% [markdown]
# card payment receipt

# %%
cardno=input('enter cardno')
lastdigits=cardno[12:]
four='x' *4 +' '
dispno=four*3+lastdigits
print(dispno)
# Out:
# enter cardno 3254589742256
# xxxx xxxx xxxx 6
