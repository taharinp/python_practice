# %%
s='\u0915\u0916\0917'

# %%
s='\u03b1'

# %% [markdown]
# 2.ESCAPE SEQUENCE :PRINTABLE AND NON PRINTABLE

# %%
print('\N{dollar sign}')
# Out:
# $

# %%
print('\N{registered sign}')
# Out:
# ®

# %%
print('\N{grinning face}')
# Out:
# 😀

# %% [markdown]
# 3.PRINT FUNCTION

# %%
print('hi',52,36.2)
# Out:
# hi 52 36.2

# %%
print('hi',52,36.2,sep='-')
# Out:
# hi-52-36.2

# %%
print('hi',52,36.2,sep='-&')
# Out:
# hi-&52-&36.2

# %%
print('helo')
print('world')
# Out:
# helo
# world

# %%
print('helo',end='\t')
print('world')
# Out:
# helo	world

# %% [markdown]
# *FORMATTED PRINTING*

# %%
item='memory'
size=32
price=11.75
print('cost of %dGB %s is $%.2f' % (size, item, price))
# Out:
# cost of 32GB memory is $11.75

# %%
data=200
print('%d' %(data))
# Out:
# 200

# %%
data=200
print('%x' %(data))
# Out:
# c8

# %%
data=300
print('start {0:15} end'.format(data))
# Out:
# start             300 end

# %%
data=300
print('start {0:^15o} end'.format(data))
# Out:
# start       454       end

# %%
data=300
print('start {0:^15,} end'.format(data))
# Out:
# start       300       end

# %%
data=300
print('start {0:^15e} end'.format(data))
# Out:
# start  3.000000e+02   end

# %%
item='memory'
size=32
price=11.75
print(f'{size}GB {item:^10} in ${price}')
# Out:
# 32GB   memory   in $11.75
