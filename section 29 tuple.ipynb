# %%
t1=(1,2,3,4,5)
t1
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t1)
# Out:
# tuple

# %%
t2=tuple([1,2,3,4])
t3=tuple('python')
t4=tuple(range(1,5))

# %%
print(t2)
print(t3)
print(t4)
# Out:
# (1, 2, 3, 4)
# ('p', 'y', 't', 'h', 'o', 'n')
# (1, 2, 3, 4)

# %%
t5=()

# %%
t1=(*(x for x in range(1,5)),)
t1
# Out:
# (1, 2, 3, 4)

# %%
t1=tuple(x for x in range(1,5))
t1
# Out:
# (1, 2, 3, 4)

# %%
t1=(*(x.lower() for x in 'PYThon'),)
t1
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
t1=tuple(x for x in 'pyTHon')
t1
# Out:
# ('p', 'y', 'T', 'H', 'o', 'n')

# %%
t1=tuple(int(x) for x in '156')
t1
# Out:
# (1, 5, 6)

# %%
t1=tuple(x for x in 'abdja*2434' if x.isalpha())
t1
# Out:
# ('a', 'b', 'd', 'j', 'a')

# %%
t1=(*(int(x) for x in '156'),)
t1
# Out:
# (1, 5, 6)

# %%
t1=(*(x for x in 'abdja*2434' if x.isalpha()),)
t1
# Out:
# ('a', 'b', 'd', 'j', 'a')

# %%
t1=(1,2,3,4,5)
t1[3]
# Out:
# 4

# %%
t1=(1,2,3,4,5)
t1[:]
# Out:
# (1, 2, 3, 4, 5)

# %%
t1=(1,2,3,4,5)
t1[2:5]
# Out:
# (3, 4, 5)

# %%
t1=(1,2,3,4,5)
t1[::]
# Out:
# (1, 2, 3, 4, 5)

# %%
t1=(1,2,3,4,5)
t1[::-2]
# Out:
# (5, 3, 1)

# %%
t1=(1,2,3,4,5)
t1[::2]
# Out:
# (1, 3, 5)

# %%
t1=(1,2,3,4,5)
t1[-3:0:-1]
# Out:
# (3, 2)

# %%
t1=(1,2,3)
t2=(7,5)
t3=t1+t2
t3
# Out:
# (1, 2, 3, 7, 5)

# %%
t1=(1,2,3)

t3=t1*3
t3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
t=1,2,3,4
a,s,f,g=t
print(a,s,f,g)
# Out:
# 1 2 3 4

# %%
t=1,2,3,4
a,b,*c=t

# %%
print(a,b,c)
# Out:
# 1 2 [3, 4]
