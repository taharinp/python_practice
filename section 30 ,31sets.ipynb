# %%
s1={}
type(s1)
# Out:
# dict

# %%
s1={1,2,3}
s1
# Out:
# {1, 2, 3}

# %%
s1.add(398)
s1
# Out:
# {1, 2, 3, 398}

# %% [markdown]
# union

# %%
s1={1,2,3,5,7}

# %%
s2={5,7,9,10,11}

# %%
s3=s1.union(s2)
s3
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11, 398}

# %% [markdown]
# intersection

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1.intersection(s2)
s3
# Out:
# {5, 7}

# %% [markdown]
# difference

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1.difference(s2)
s3
# Out:
# {1, 2, 3}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s2.difference(s1)
s3
# Out:
# {9, 10, 11}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s2.difference_update(s1)
s2
# Out:
# {9, 10, 11}

# %% [markdown]
# symmetric difference

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1.symmetric_difference(s2)
s3
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s2.symmetric_difference(s1)
s3
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s2.symmetric_difference_update(s1)
s2
# Out:
# {1, 2, 3, 9, 10, 11}

# %% [markdown]
# operators on sets

# %% [markdown]
# union

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1|s2
s3
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s1=s1|s2
s1
# Out:
# {1, 2, 3, 5, 7, 9, 10, 11}

# %% [markdown]
# intersection

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1&s2
s3
# Out:
# {5, 7}

# %% [markdown]
#  intersection update

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s1&=s2
s1
# Out:
# {5, 7}

# %% [markdown]
# difference

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1-s2
s3
# Out:
# {1, 2, 3}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s2-s1
s3
# Out:
# {9, 10, 11}

# %% [markdown]
# dfference update

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s1-=s2
s1
# Out:
# {1, 2, 3}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s2-=s1
s2
# Out:
# {9, 10, 11}

# %% [markdown]
# symmetric difference

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s3=s1^s2
s3
# Out:
# {1, 2, 3, 9, 10, 11}

# %% [markdown]
# symmetric difference update

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s1^=s2
s1
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
s1={1,2,3,5,7}
s2={5,7,9,10,11}
s2^=s1
s2
# Out:
# {1, 2, 3, 9, 10, 11}

# %% [markdown]
# add()

# %%
s1={1,2,3,4,5}
s1.add(89)
s1
# Out:
# {1, 2, 3, 4, 5, 89}

# %%
s1.add((34,65))
s1
# Out:
# {(34, 65), 1, 2, 3, 4, 5, 89}

# %%
s1={1,2,3,4,5}
s1.update((89,90))
s1
# Out:
# {1, 2, 3, 4, 5, 89, 90}

# %%
s1={1,2,3,4,5}
s2=s1.copy()
s2
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2,3,4,5}
s1.pop()
# Out:
# 1

# %%
s1={1,2,3,4,5}
s1.pop()
# Out:
# 1

# %%
s1={1,2,3,4,5}
s1.discard(3)

# %%
s1
# Out:
# {1, 2, 4, 5}

# %%
s1={1,2,3,4,5}
s1.discard(30)
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2,3,4,5}
s1.remove(3)
s1
# Out:
# {1, 2, 4, 5}

# %%
s1={1,(2,3),4,5}
s1.remove((2,3))
s1
# Out:
# {1, 4, 5}

# %%
s1={1,2,3,4,5}
s1.clear()
s1
# Out:
# set()

# %% [markdown]
# comprehensions

# %%
s1={x for x in range(1,5)}
s1
# Out:
# {1, 2, 3, 4}

# %%
s2={x**2 for x in [-2,-1,0,1,2]}
s2
# Out:
# {0, 1, 4}

# %%
s2={x.lower() for  x in 'philLIPINEs'}
s2
# Out:
# {'e', 'h', 'i', 'l', 'n', 'p', 's'}

# %% [markdown]
# scrambled words

# %%
word_set = {'plea', 'medical', 'listen', 'leap', 'decimal', 'silent', 'pale', 'enlist'}
result = set()
print('scrambled words pairs:')
for word1 in word_set:
    for word2 in word_set:
        if word1 != word2 and sorted(word1)==sorted(word2):
            pair=tuple(sorted((word1,word2)))
            result.add(pair)
    




for pair in result:
    print(pair)
# Out:
# scrambled words pairs:
# ('pale', 'plea')
# ('decimal', 'medical')
# ('leap', 'plea')
# ('listen', 'silent')
# ('enlist', 'silent')
# ('leap', 'pale')
# ('enlist', 'listen')

# %% [markdown]
# plagiarism challenge

# %%
import re

str1 = ('Time is the most valuable thing we have,'
        ' and once lost, it never returns.')
str2 = ("We never get time back once it's "
    "gone—it's truly the most valuable resource.")

words1=re.findall(r'\w+',str1.lower())
words2=re.findall(r'\w+',str2.lower())
wset1=set(words1)
wset2=set(words2)
common=wset1&wset2
unique=wset1|wset2



ratio = len(common) / len(unique)


print(f"Jaccard Similarity:{ratio:.2f}")
# Out:
# Jaccard Similarity:0.40
