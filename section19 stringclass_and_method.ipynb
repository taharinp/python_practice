# %%
s1='hello'
print(type(s1))

# %%
s='hello how are you'

# %% [markdown]
# 1.find

# %%
x=s.find('o')

# %%
print(x)
# Out:
# 4

# %%
x=s.find('how')
print(x)
# Out:
# 6

# %%
x=s.find('q')
print(x)
# Out:
# -1

# %%
x=s.find('o',5)

# %%
print(x)
# Out:
# 7

# %%
x=s.find('r',5,16)
print(x)
# Out:
# 11

# %% [markdown]
# 2.rfind

# %%
x=s.rfind('o')
print(x)
# Out:
# 15

# %%
x=s.rfind('o',0,15)
print(x)
# Out:
# 7

# %%
x=s.rfind('q')
print(x)
# Out:
# -1

# %% [markdown]
# 3.index

# %%
x=s.index('o')
print(x)
# Out:
# 4

# %%
x=s.index('how')
print(x)
# Out:
# 6

# %% [markdown]
# 4.rindex

# %%
x=s.rindex('o')
print(x)
# Out:
# 15

# %% [markdown]
# x=s.rindex('o',0,15)
# print(x)

# %% [markdown]
# 5.count

# %%
x=s.count('o')
print(x)
# Out:
# 3

# %%
x=s.count('me')
print(x)
# Out:
# 0

# %% [raw]
# STRING ALIGNMENT AND PADDING

# %%
s='hello'

# %%
s.ljust(7,'*')
# Out:
# 'hello**'

# %%
s.rjust(45)
# Out:
# '                                        hello'

# %%
s.rjust(7,'-')
# Out:
# '--hello'

# %%
s.center(15)
# Out:
# '     hello     '

# %%
s.center(7,'*')
# Out:
# '*hello*'

# %%
s.zfill(7)
# Out:
# '00hello'

# %% [markdown]
# STRIP METHODS

# %%
s = '        hello'

# %%
s.lstrip()
# Out:
# 'hello'

# %%
s='****hello'
x=s.lstrip('*')
print(x)
# Out:
# hello

# %%
s='helli!!!!'

# %%
s.rstrip('!')
# Out:
# 'helli'

# %%
s='#hello#'

# %%
s.strip('#')
# Out:
# 'hello'

# %%
s='##@!hello@#$%$'
x=s.strip('#!@$%$')
print(x)
# Out:
# hello

# %% [markdown]
# joining and splitting a string

# %%
s='a-b-c-d'

# %%
s.replace('-',',')
# Out:
# 'a,b,c,d'

# %%
s='abc@gmail.com'

# %%
s.replace('gmail','yahoo')
# Out:
# 'abc@yahoo.com'

# %% [markdown]
# join

# %%
s='xyz'

# %%
s2='abc'

# %%
s3=s.join(s2)

# %%
print(s3)
# Out:
# axyzbxyzc

# %%
s1='/@'
s2='avd'
s3=s2.join(s1)
print(s3)
# Out:
# /avd@

# %% [markdown]
# split

# %%
s='taharin-jah-angir-pa-tel'

# %%
s2=s.split()
print(s2)
# Out:
# ['taharin-jah-angir-pa-tel']

# %%
s.split('h')
# Out:
# ['ta', 'arin-ja', '-angir-pa-tel']

# %%
s.split('-')
# Out:
# ['taharin', 'jah', 'angir', 'pa', 'tel']

# %%
s.split('-',1)
# Out:
# ['taharin', 'jah-angir-pa-tel']

# %% [markdown]
# PREFIX AND SUFFIX OF STRING

# %%
s1='python is very easy'

# %%
s1.startswith('is')
# Out:
# False

# %%
s1.startswith('is',7)
# Out:
# True

# %%
s1.endswith('easy')
# Out:
# True

# %%
s1.removeprefix('py')
# Out:
# 'thon is very easy'

# %%
s1.removesuffix('sy')
# Out:
# 'python is very ea'

# %%
s1.partition('y')
# Out:
# ('p', 'y', 'thon is very easy')

# %%
s1.rpartition('y')
# Out:
# ('python is very eas', 'y', '')

# %% [markdown]
# CASE CONVERSION METHOD

# %%
s='hello dear'

# %%
s.capitalize()
# Out:
# 'Hello dear'

# %%
s.upper()
# Out:
# 'HELLO DEAR'

# %%
s.lower()
# Out:
# 'hello dear'

# %%
s.title()
# Out:
# 'Hello Dear'

# %%
s.swapcase()
# Out:
# 'HELLO DEAR'

# %%
s.casefold()
# Out:
# 'hello dear'

# %% [markdown]
# INQUIRY METHOD

# %%
s='HELLO'

# %%
s.islower()
# Out:
# False

# %%
s.isalpha()
# Out:
# True

# %%
s.isupper()
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %%
s='    '

# %%
len(s)
# Out:
# 4

# %%
s.isspace()
# Out:
# True

# %%
s='a\nsaksu'
s.isprintable()
# Out:
# False

# %%
s.isidentifier()
# Out:
# False

# %%
s='356'

# %%
s.isdigit()
# Out:
# True

# %%
'-235'.isnumeric()
# Out:
# False

# %%
'246-3'.isdecimal()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
's'.isascii()
# Out:
# True

# %%
s.isalnum()
# Out:
# True
