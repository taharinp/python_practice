# %%
import time

# %%
time.time()
# Out:
# 1772200543.0616746

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=2, tm_mday=27, tm_hour=19, tm_min=25, tm_sec=55, tm_wday=4, tm_yday=58, tm_isdst=0)

# %%
import datetime

# %%
time.ctime()
# Out:
# 'Fri Feb 27 19:29:00 2026'

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 2, 27, 19, 29, 20, 314149)

# %%
dt.month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dt.month
#
# NameError: name 'dt' is not defined
