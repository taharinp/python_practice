# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")

a1 = Dog()
a2 = Cat()

a1.sound()
a2.sound()
# Out:
# Dog barks
# Cat meows

# %%
class Bird:
    def fly(self):
        print("Bird flying")

class Airplane:
    def fly(self):
        print("Airplane flying")

def start_flying(obj):
    obj.fly()

b = Bird()
a = Airplane()

start_flying(b)
start_flying(a)
# Out:
# Bird flying
# Airplane flying
