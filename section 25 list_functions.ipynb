# %% [markdown]
# append

# %%
l1=[1,2,3,4,5]

# %%
l1.append(6)
l1.append('python')
l1.append([112,13])
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 'python', [112, 13]]

# %%
l1=[1,2,3,4,5]
l1[5:5]=[10]
print(l1)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
l1[len(l1):]=[10]
print(l1)
# Out:
# [1, 2, 3, 4, 5, 10, 10]

# %%
l1=[1,2,3,4,5]
l1.extend([12,34,67])
print(l1)
# Out:
# [1, 2, 3, 4, 5, 12, 34, 67]

# %%
l1=[1,2,3,4,5]
l1.extend('python')
print(l1)
# Out:
# [1, 2, 3, 4, 5, 'p', 'y', 't', 'h', 'o', 'n']

# %%
l1=[1,2,3,4,5]
l1.extend(range(5,8))
print(l1)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7]

# %%
l1=[1,2,3,4,5]
l1.extend('python')
print(l1)
# Out:
# [1, 2, 'python', 3, 4, 5]

# %%
l1=[1,2,3,4,5]
l1.insert(4,786)
print(l1)
# Out:
# [1, 2, 3, 4, 786, 5]

# %%
l1=[1,2,3,4,5]

# %%
l2=l1.copy()
print(l2)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# removing elements

# %%
l1=[1,2,3,4,5]
l1.pop()
# Out:
# 5

# %%
l1=[1,2,3,4,5]
l1.pop(2)
# Out:
# 3

# %%
l1=[1,2,3,4,3,5]
l1.remove(3)
print(l1)
# Out:
# [1, 2, 4, 3, 5]

# %%
l1=[1,2,3,4,3,5]
l1.clear()

# %%
l1=[1,2,3,4,3]
del l1[4]
l1
# Out:
# [1, 2, 3, 4]

# %%
l1=[1,2,3,4,3]
del l1[1:4]
l1
# Out:
# [1, 3]

# %% [markdown]
# index and sorting

# %%
l1=[10,20,30,40,20,30,10]
l1.index(20)
# Out:
# 1

# %%
l1=[10,20,30,40,20,30,10]
l1.index(20,2)
# Out:
# 4

# %%
l1=[10,20,30,40,20,30,10]
l1.index(20,2,6)
# Out:
# 4

# %%
l1=[10,20,30,40,20,30,10]
l1.count(20)
# Out:
# 2

# %%
l1=[10,20,30,40,20,30,10]
l1.reverse()
l1
# Out:
# [10, 30, 20, 40, 30, 20, 10]

# %%
l1=[70,80,20,78,30,40,20,30,10]
l1.sort()
l1
# Out:
# [10, 20, 20, 30, 30, 40, 70, 78, 80]

# %%
l1=[70,80,20,78,30,40,20,30,10]
l1.sort(reverse=True)
l1
# Out:
# [80, 78, 70, 40, 30, 30, 20, 20, 10]

# %%
l1=['coat','python','black','cat']
l1.sort()
l1
# Out:
# ['black', 'cat', 'coat', 'python']

# %%
l1=['coat','python','black','cat']
l1.sort(key=len)
l1
# Out:
# ['cat', 'coat', 'black', 'python']
