# %%
d1={1:'one',2:'two',3:'three',4:'four'}
d1[4]
# Out:
# 'four'

# %%
d1[3]='abx'

# %%
d1
# Out:
# {1: 'one', 2: 'two', 3: 'abx', 4: 'four'}

# %%
d1[5]='five'
d1
# Out:
# {1: 'one', 2: 'two', 3: 'abx', 4: 'four', 5: 'five'}

# %%
for i in d1:
    print(i,d1[i])
# Out:
# 1 one
# 2 two
# 3 abx
# 4 four
# 5 five

# %%
d1=dict([(1,'one'),(2,'two'),(3,'three'),(4,'four')])
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
l1=[1,2]
l2=['one','two']
d1=dict(zip(l1,l2))
print(d1)
# Out:
# {1: 'one', 2: 'two'}

# %%
l2=['one','two','three']
d1=dict(enumerate(l2,start=1))
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
l2=[(1,'one'),(2,'two'),(3,'three')]
d1={x:y for x,y in l2}
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
l1=[1,2]
l2=['one','two']
d1={x:y for x,y in zip(l1,l2)}
print(d1)
# Out:
# {1: 'one', 2: 'two'}

# %%
l2=['one','two','three']
d1={ x:y for x,y in enumerate (l2,start=1)}
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
d1={1:'one',2:'two',3:'three',4:'four'}

# %%
d1.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
for x in d1.keys():
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
d1={1:'one',2:'two',3:'three',4:'four'}
d1.values()
for x in d1.values():
    print(x)
# Out:
# one
# two
# three
# four

# %%
d1={1:'one',2:'two',3:'three',4:'four'}
d1.items()
for x,y in d1.items():
    print(x,y)
# Out:
# 1 one
# 2 two
# 3 three
# 4 four

# %%
d1.get(3)
# Out:
# 'three'

# %%
d1[4]
# Out:
# 'four'

# %%
d1.get(5,'missing')
# Out:
# 'missing'

# %%
d1.setdefault(3)
# Out:
# 'three'

# %%
d1.setdefault(5)

# %%
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: None}

# %%
d1.setdefault(5,'undefined')

# %%
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: None}

# %%
d1={1:'one',2:'two',3:'three',4:'four'}
d2={5:'five'}
d1.update(d2)
d1
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}

# %%
l1=[1,2,3,4]
d1=dict.fromkeys(l1)
d1
# Out:
# {1: None, 2: None, 3: None, 4: None}

# %%
l1=[1,2,3,4]
d1=dict.fromkeys(l1,'unknown')
d1
# Out:
# {1: 'unknown', 2: 'unknown', 3: 'unknown', 4: 'unknown'}

# %%
d1={1:'one',2:'two',3:'three',4:'four'}
d2=d1.copy()
d2
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
d1.pop(2)
d1
# Out:
# {1: 'one', 3: 'three', 4: 'four'}

# %%
d1.pop(5,'missing')
# Out:
# 'missing'

# %%
d1.popitem()
# Out:
# (4, 'four')

# %%
d1.clear()
d1
# Out:
# {}

# %% [markdown]
# login tracker

# %%
users = ['john', 'bob', 'alex', 'alice', 'charlie', 'john',
         'alex', 'alice', 'john', 'alex']

logins = {}

for username in users:
    if username in logins:
        logins[username] +=1
    else:
        logins[username] =1






for user, count in logins.items():
    print(f"{user:8} : {count} logins")
# Out:
# john     : 3 logins
# bob      : 1 logins
# alex     : 3 logins
# alice    : 2 logins
# charlie  : 1 logins

# %% [markdown]
# Invert dictionary

# %%
original = {'a': 1, 'b': 2, 'c': 1, 'd': 2, 'e': 3, 'f': 2}

inverted = {}

for key, value in original.items():
    if value not in inverted:
        inverted[value]={key}
    else:
        inverted[value].add(key)
        pri
    
    




print("Inverted Dict:", inverted)

# %% [markdown]
# isomorphic string

# %%
str1, str2 = 'paper', 'title'

flag = True

if len(str1) != len(str2):
    flag = False
else:
    map1, map2 = {}, {}
    for c1,c2 in zip(str1,str2):
        if c1 in map1:
            if map1[c1] !=c2:
                flag=false
            else:
                map1[c1]=c2
                if c2 in map2:
                    if map2[c2] !=c1:
                        flag=false
                    else:
                        map2[c2]=c1
                        
   
if flag:
    print('Isomorphic String')
else:
    print('Not a Isomorphic String')
# Out:
# Isomorphic String

# %% [markdown]
# nested list to dictionaries

# %%
header = ['name', 'age', 'city']
data = [
    ['James', 25, 'NY'],
    ['Kiran', 30, 'DEL'],
    ['Smith', 24, 'PAR'],
    ['Raj', 27, 'DEL']
]

result = []
length = len(header)
for i in range(length):
    newdict={}
    for row in data:
        if row[i] not in newdict:
            newdict[row[i]]=[row]
        else:
            newdict[row[i]].append(row)
    result.append(newdict)
            

print("Dictionaries:")
for i in range(length):
   
    print('\n' + header[i])
    for key, value in result[i].items():
       
        print(f"{key:<10}:{value}")
# Out:
# Dictionaries:
#
# name
# James     :[['James', 25, 'NY']]
# Kiran     :[['Kiran', 30, 'DEL']]
# Smith     :[['Smith', 24, 'PAR']]
# Raj       :[['Raj', 27, 'DEL']]
#
# age
# 25        :[['James', 25, 'NY']]
# 30        :[['Kiran', 30, 'DEL']]
# 24        :[['Smith', 24, 'PAR']]
# 27        :[['Raj', 27, 'DEL']]
#
# city
# NY        :[['James', 25, 'NY']]
# DEL       :[['Kiran', 30, 'DEL'], ['Raj', 27, 'DEL']]
# PAR       :[['Smith', 24, 'PAR']]

# %%
import uuid


items = [['laptop', 1200],
         ['mouse', 20],
         ['keyboard', 30],
         ['tablet', 200]]

item_data = {}
for item in items:
    id=uuid.uuid5(uuid.NAMESPACE_OID,item[0] )
    key=id.hex[:6]
    item_data[key]=item
    





print("Item Data:")
for k, v in item_data.items():
    print(f"{k}: {v}")
# Out:
# Item Data:
# bd0220: ['laptop', 1200]
# db0304: ['mouse', 20]
# c2f82e: ['keyboard', 30]
# 56831a: ['tablet', 200]
